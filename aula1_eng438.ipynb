# %% [markdown]
# <a href="https://colab.research.google.com/github/assuerolopo/ciencia_de_dados/blob/main/aula1_eng438.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dados = pd.read_excel('/content/drive/MyDrive/volleyball2019_aula1.xlsx')

# %%
dados.isna().sum()
# Out:
# Nome                  0
# Ranking Geral         0
# Ranking em 2020       0
# Nacionalidade         0
# Posição               0
# Data de Nascimento    0
# Altura (cm)           0
# Peso (kg)             0
# Salto (cm)            0
# Bloqueio (cm)         0
# Mão Dominante         3
# Pontos do país        7
# Pontos                0
# dtype: int64

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Nome                30 non-null     object
#  1   Ranking Geral       30 non-null     int64
#  2   Ranking em 2020     30 non-null     int64
#  3   Nacionalidade       30 non-null     object
#  4   Posição             30 non-null     object
#  5   Data de Nascimento  30 non-null     object
#  6   Altura (cm)         30 non-null     int64
#  7   Peso (kg)           30 non-null     int64
#  8   Salto (cm)          30 non-null     int64
#  9   Bloqueio (cm)       30 non-null     int64
#  10  Mão Dominante       27 non-null     object
#  11  Pontos do país      23 non-null     float64
#  12  Pontos              30 non-null     float64
# dtypes: float64(2), int64(6), object(5)
# memory usage: 3.2+ KB

# %%
dados.describe()
# Out:
#        Ranking Geral  Ranking em 2020  Altura (cm)  Peso (kg)  Salto (cm)  \
# count      30.000000        30.000000    30.000000  30.000000   30.000000
# mean      351.166667       266.300000   187.833333  72.133333  307.633333
# std       390.695497       497.398415     8.436715   7.445125   17.440506
# min         3.000000         0.000000   168.000000  55.000000  250.000000
# 25%        52.500000         4.500000   183.500000  68.000000  302.000000
# 50%       183.500000        21.000000   190.000000  74.000000  311.000000
# 75%       549.250000       251.500000   194.000000  77.750000  315.750000
# max      1601.000000      1837.000000   201.000000  84.000000  336.000000
#
#        Bloqueio (cm)  Pontos do país       Pontos
# count      30.000000       23.000000    30.000000
# mean      296.366667      181.391304   492.541667
# std        16.283021       89.315956   181.231626
# min       245.000000       30.000000   345.000000
# ...

# %%
dados.loc[dados["Salto (cm)"] > 319]["Nome"]
# Out:
# 0                Ting Zhu
# 3       Tijana BoÅ¡koviÄ
# 4             Paola Egonu
# 9      Brayelin MartÃ­nez
# 12         Melissa Vargas
# 22    Nataliya Goncharova
# Name: Nome, dtype: object

# %%
dados["Nacionalidade"].unique()
# Out:
# array(['China', 'Brazil', 'Serbia', 'Italy', 'Dominican Republic', 'USA',
#        'Japan', 'Turkey', 'Cuba', 'Russia', 'Russia, Ukraine', 'Mexico'],
#       dtype=object)

# %%
dados['Nacionalidade'].value_counts()
# Out:
# Brazil                7
# USA                   6
# China                 3
# Dominican Republic    3
# Turkey                3
# Serbia                2
# Italy                 1
# Japan                 1
# Cuba                  1
# Russia                1
# Russia, Ukraine       1
# Mexico                1
# Name: Nacionalidade, dtype: int64

# %%
dados1 = dados.set_index('Nome', drop = True) #Transforma coluna nome em index
dados1
# Out:
#                        Ranking Geral  Ranking em 2020       Nacionalidade  \
# Nome
# Ting Zhu                           3               23               China
# Macris Carneiro                  176               19              Brazil
# Gabriela GuimarÃ£es               31               13              Brazil
# Tijana BoÅ¡koviÄ                 28                3              Serbia
# Paola Egonu                      134                2               Italy
# Bethania De La Cruz               23               25  Dominican Republic
# Kelsey Robinson                  180                0                 USA
# Mayu Ishikawa                   1601             1668               Japan
# Andrea Drews                     621               14                 USA
# Brayelin MartÃ­nez                83                0  Dominican Republic
# Simge Åebnem AkÃ¶z              405                4              Turkey
# Yingying Li                      511               75               China
# ...

# %%
dados[["Peso (kg)", "Nome"]]
# Out:
#     Peso (kg)                   Nome
# 0          78               Ting Zhu
# 1          68        Macris Carneiro
# 2          65    Gabriela GuimarÃ£es
# 3          84      Tijana BoÅ¡koviÄ
# 4          70            Paola Egonu
# 5          68    Bethania De La Cruz
# 6          75        Kelsey Robinson
# 7          65          Mayu Ishikawa
# 8          77           Andrea Drews
# 9          83     Brayelin MartÃ­nez
# 10         55    Simge Åebnem AkÃ¶z
# 11         78            Yingying Li
# 12         76         Melissa Vargas
# 13         60         LÃ©ia Nicolosi
# 14         81             Mara LeÃ£o
# 15         75            Karsta Lowe
# 16         68       Jineiry Martinez
# 17         62           Mayany Souza
# 18         83           TeTori Dixon
# 19         78         Irina Koroleva
# 20         78        Caroline Gattaz
# 21         73     Ana Carolina Silva
# 22         75    Nataliya Goncharova
# 23         68       Maja OgnjenoviÄ
# ...

# %%
dados['Pontos do país'] = dados['Pontos do país'].fillna('0')
